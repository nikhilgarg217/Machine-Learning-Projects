# %% [markdown]
# # -------------------------------------House Prices Prediction---------------------------------------

# %% [markdown]
# ### Competition Link:- https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %% [markdown]
# ## Competition Description

# %% [markdown]
# Ask a home buyer to describe their dream house, and they probably
# wont begin with the height of the basement ceiling or the proximity to an east-west railroad.
# But this playground competition dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.

# %% [markdown]
# ### **Goal: Creating a machine learning model for predicting house price .**

# %% [markdown]
# ### Attribute Information:-

# %% [markdown]
# 1. SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# 2. MSSubClass: The building class
# 3. MSZoning: The general zoning classification
# 4. LotFrontage: Linear feet of street connected to property
# 5. LotArea: Lot size in square feet
# 6. Street: Type of road access
# 7. Alley: Type of alley access
# 8. LotShape: General shape of property
# 9. LandContour: Flatness of the property
# 10. Utilities: Type of utilities available
# 11. LotConfig: Lot configuration
# 12. LandSlope: Slope of property
# 13. Neighborhood: Physical locations within Ames city limits
# 14. Condition1: Proximity to main road or railroad
# 15. Condition2: Proximity to main road or railroad (if a second is present)
# 16. BldgType: Type of dwelling
# 17. HouseStyle: Style of dwelling
# 18. OverallQual: Overall material and finish quality
# 19. OverallCond: Overall condition rating
# 20. YearBuilt: Original construction date
# 21. YearRemodAdd: Remodel date
# 22. RoofStyle: Type of roof
# 23. RoofMatl: Roof material
# 24. Exterior1st: Exterior covering on house
# 25. Exterior2nd: Exterior covering on house (if more than one material)
# 26. MasVnrType: Masonry veneer type
# 27. MasVnrArea: Masonry veneer area in square feet
# 28. ExterQual: Exterior material quality
# 29. ExterCond: Present condition of the material on the exterior
# 30. Foundation: Type of foundation
# 31. BsmtQual: Height of the basement
# 32. BsmtCond: General condition of the basement
# 33. BsmtExposure: Walkout or garden level basement walls
# 34. BsmtFinType1: Quality of basement finished area
# 35. BsmtFinSF1: Type 1 finished square feet
# 36. BsmtFinType2: Quality of second finished area (if present)
# 37. BsmtFinSF2: Type 2 finished square feet
# 38. BsmtUnfSF: Unfinished square feet of basement area
# 39. TotalBsmtSF: Total square feet of basement area
# 40. Heating: Type of heating
# 41. HeatingQC: Heating quality and condition
# 42. CentralAir: Central air conditioning
# 43. Electrical: Electrical system
# 44. 1stFlrSF: First Floor square feet
# 45. 2ndFlrSF: Second floor square feet
# 46. LowQualFinSF: Low quality finished square feet (all floors)
# 47. GrLivArea: Above grade (ground) living area square feet
# 48. BsmtFullBath: Basement full bathrooms
# 49. BsmtHalfBath: Basement half bathrooms
# 50. FullBath: Full bathrooms above grade
# 51. HalfBath: Half baths above grade
# 52. Bedroom: Number of bedrooms above basement level
# 53. Kitchen: Number of kitchens
# 54. KitchenQual: Kitchen quality
# 55. TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 56. Functional: Home functionality rating
# 57. Fireplaces: Number of fireplaces
# 58. FireplaceQu: Fireplace quality
# 59. GarageType: Garage location
# 60. GarageYrBlt: Year garage was built
# 61. GarageFinish: Interior finish of the garage
# 62. GarageCars: Size of garage in car capacity
# 63. GarageArea: Size of garage in square feet
# 64. GarageQual: Garage quality
# 65. GarageCond: Garage condition
# 66. PavedDrive: Paved driveway
# 67. WoodDeckSF: Wood deck area in square feet
# 68. OpenPorchSF: Open porch area in square feet
# 69. EnclosedPorch: Enclosed porch area in square feet
# 70. 3SsnPorch: Three season porch area in square feet
# 71. ScreenPorch: Screen porch area in square feet
# 72. PoolArea: Pool area in square feet
# 73. PoolQC: Pool quality
# 74. Fence: Fence quality
# 75. MiscFeature: Miscellaneous feature not covered in other categories
# 76. MiscVal: $Value of miscellaneous feature
# 77. MoSold: Month Sold
# 78. YrSold: Year Sold
# 79. SaleType: Type of sale
# 80. SaleCondition: Condition of sale

# %% [markdown]
# **-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ## Steps:-

# %% [markdown]
# <b>    1. Importing libraries & Dataset</b>
#
# <b>    2. Analyzing the data & pre-processing</b>
#
# <b>    3. EDA/Data Visualization</b>
#
# <b>    4. Classification</b>
#
#         4.1 KNN
#
#         4.2 Decision tree
#
#         4.3 Logistic Regression
#
# <b>    5. Clustering</b>
#
# <b>    6. Wrapper Method</b>
#
# <b>    7. Regression</b>
#
#         7.1 Linear Regression
#
#         7.2 Polynomial Regression
#
#         7.3 XGBoost
#
#         7.4 Random Forest
#
# <b>    8. Prediction on test data</b>

# %% [markdown]
# **-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ## **1. Import & Load Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#prepairing data
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

#libraries for classification
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

#performance
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

#libraries for clustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

#librariesfor regression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# read the train data using pandas dataframe
df = pd.read_csv('train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# read the test data using pandas dataframe
test = pd.read_csv('test.csv')

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ##  **2. Analyzing the data & data pre-processing**

# %%
df.shape
# Out:
# (1460, 81)

# %%
# describe function
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# finding numerical columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newdf = df.select_dtypes(include=numerics)

# %%
newdf.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# checking null values
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# Dropping Catagorical Columns From Train Data
abc=df.drop(labels=['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PoolQC','Fence','MiscFeature','SaleType','SaleCondition','PavedDrive'
],axis=1)
abc
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
# Dropping catagorical Columns From Test Data
test=test.drop(labels=['MSZoning','Street','Alley','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','ExterQual','ExterCond','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Heating','HeatingQC','Electrical','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PoolQC','Fence','MiscFeature','SaleType','SaleCondition','PavedDrive'
],axis=1)
test
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  GarageArea  \
# ...

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# > ### 1. Show the House Sale according to Sale Price?

# %%
# Distplot
plt.figure(figsize=(10,5))
sns.distplot(df['SalePrice']);

# %% [markdown]
# The graph shows that price is not normal,it is right skewed because we have long tail in right which means that majority of records have lower price of house and we have limited number of house at that price.

# %%
# Boxplot
plt.figure(figsize=(10,5))
sns.boxplot(df['SalePrice']);

# %% [markdown]
# > ### 2. Show the size of Living Area according to Sale Price?

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# This Graph shows that as the price of the house increases the living area also increases.

# %% [markdown]
# > ### 3. Show the OverallQual(Overall Quality) of House according to SalePrice

# %%
#box plot overallqual/saleprice
var = 'OverallQual'
data = pd.concat([df['SalePrice'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# This graph is showing that as the sale price is increasing the quality of house is increasing.

# %% [markdown]
# > ### 4. Show the coorelation between the columns?

# %%
# Heat Map
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), square=True);

# %% [markdown]
# The heat map shows the coorealation so more lighter the colour more is the coorelation.

# %% [markdown]
# > ### 5. Show the Columns Having Null Values

# %%
# bar graph
## Percentage wise calculating Null Values
all_data = pd.concat((df,test)).reset_index(drop=True)

nindex, nfeatures = all_data.shape
## Get the dataframe with all the features and SUM of the NaN values present
df_null_count = all_data.isnull().sum().to_frame().rename({0:"Sum"}, axis=1)

## Select only those features who have atleast 1 NaN value
df_null_count = df_null_count[df_null_count['Sum'] > 0]

## Change the SUM to PERCENTAGE 
df_null_count['Sum'] = df_null_count['Sum']*(100/nindex)

## Plot a Horizontal Bar Graph
df_null_count.sort_values(by="Sum", ascending=True).plot(
    kind='barh', figsize=(12,10), fontsize=14, colormap="RdBu_r", title="Percentage wise null values"
)
plt.show()

# %% [markdown]
# This graph shows the number of null values in each column

# %% [markdown]
# ## 4. CLASSIFICATION

# %%
# Columns selected are LotArea,bsmtFinSF1,GrLivArea,SalePrice
X = df.iloc[:, [4,34,45,80]].values
# Columns selected is PavedDrive
y = df.iloc[:, 65].values

# %%
X
# Out:
# array([[  8450,    706,      0, 208500],
#        [  9600,    978,      0, 181500],
#        [ 11250,    486,      0, 223500],
#        ...,
#        [  9042,    275,      0, 266500],
#        [  9717,     49,      0, 142125],
#        [  9937,    830,      0, 147500]], dtype=int64)

# %%
y
# Out:
# array(['Y', 'Y', 'Y', ..., 'Y', 'Y', 'Y'], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state=0)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### 4.1 KNN

# %% [markdown]
# > **K-Nearest Neighbors (KNN)  is an approach to data classification that estimates how likely a data point is to be a member of one group or the other depending on what group the data points nearest to it are in..**

# %%
classifier3 = KNeighborsClassifier(n_neighbors=5)
classifier3.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_training_3 = classifier3.predict(X_train)
y_pred_training_3
# Out:
# array(['Y', 'Y', 'Y', ..., 'Y', 'Y', 'Y'], dtype=object)

# %%
y_pred_test_3 = classifier3.predict(X_test)

# %%
acc=metrics.accuracy_score(y_test, y_pred_test_3)
print("Accuracy is :",acc)
# Out:
# Accuracy is : 0.910958904109589

# %% [markdown]
# ### 4.2 Decision Tree

# %% [markdown]
#  > **A Decision tree is a type of Supervised Machine Learning where the data is continuously split according to a certain parameter. The tree can be explained by two entities, namely decision nodes and leaves .**

# %%
classifier5 = DecisionTreeClassifier(criterion = 'entropy')
classifier5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred_training_5 = classifier5.predict(X_train)
y_pred_training_5
# Out:
# array(['Y', 'Y', 'Y', ..., 'Y', 'Y', 'Y'], dtype=object)

# %%
y_pred_test_5 = classifier5.predict(X_test)

# %%
acc=metrics.accuracy_score(y_test, y_pred_test_5)
print("Accuracy is :",acc)
# Out:
# Accuracy is : 0.8938356164383562

# %% [markdown]
# ### 4.3 Logistic Regression

# %% [markdown]
# > **Logistic Regression is a supervised Learning classification algorithm used to predict the probability of a target variable**

# %%
 #Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
classifier1 = LogisticRegression(random_state = 0)
classifier1.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred_training_1 = classifier1.predict(X_train)
y_pred_training_1
# Out:
# array(['Y', 'Y', 'Y', ..., 'Y', 'Y', 'Y'], dtype=object)

# %%
y_pred_test_1 = classifier1.predict(X_test)

# %%
acc=metrics.accuracy_score(y_test, y_pred_test_1)
print("Accuracy is :",acc)
# Out:
# Accuracy is : 0.934931506849315

# %% [markdown]
#  **Classification on logistic regression is coming out to be more accurate compared to KNN and Decision Tree.**

# %% [markdown]
# ## 5. Clustering

# %% [markdown]
# ### 5.1 Selecting Columns

# %%
# Columns selected are GrLivArea and SalePrice
X=training_set1.iloc[:,[17,38]].values
scaler = StandardScaler()
Y= scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, init = 'k-means++', max_iter=300, n_init=10)
    kmeans.fit(Y)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_coefficients = []
# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters = k, init = 'k-means++', max_iter=300, n_init=10)
    kmeans.fit(Y)
    score = silhouette_score(Y, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.plot(range(2, 11), silhouette_coefficients)
plt.title('Silhouette Coefficients')
plt.xlabel('Number of clusters')
plt.ylabel('silhouette_coefficients')
plt.show()

# %%
# calculating for 2 clusters
kmeans = KMeans(n_clusters = 2, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
plt.scatter(Y[y_kmeans == 0, 0], Y[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1') #careful
plt.scatter(Y[y_kmeans == 1, 0], Y[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') #standard
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('GriLivArea')
plt.ylabel('SalePrice')
plt.legend()
plt.show()

# %%
# calculating for 3 clusters
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
plt.scatter(Y[y_kmeans == 0, 0], Y[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1') #careful
plt.scatter(Y[y_kmeans == 1, 0], Y[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') #standard
plt.scatter(Y[y_kmeans == 2, 0], Y[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3') #Target
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('GriLivArea')
plt.ylabel('SalePrice')
plt.legend()
plt.show()

# %%
# calculating for 4 clusters
kmeans = KMeans(n_clusters = 4, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
plt.scatter(Y[y_kmeans == 0, 0], Y[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1') #careful
plt.scatter(Y[y_kmeans == 1, 0], Y[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') #standard
plt.scatter(Y[y_kmeans == 2, 0], Y[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3') #Target
plt.scatter(Y[y_kmeans == 3, 0], Y[y_kmeans == 3, 1], s = 100, c = 'pink', label = 'Cluster 4') #careful

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters')
plt.xlabel('GriLivArea')
plt.ylabel('SalePrice')
plt.legend()
plt.show()

# %%
no_of_clusters = [ 2, 3, 4] 
silhouette_coeff = []
for n_clusters in no_of_clusters: 
  
    cluster = KMeans(n_clusters = n_clusters) 
    cluster_labels = cluster.fit_predict(Y) 
  
    # The silhouette_score gives the  
    # average value for all the samples. 
    silhouette_avg = silhouette_score(Y, cluster_labels) 
    silhouette_coeff.append(silhouette_avg)
    print("For no of clusters =", n_clusters, 
          " The average silhouette_score is :", silhouette_avg)
# Out:
# For no of clusters = 2  The average silhouette_score is : 0.5325991905157584
# For no of clusters = 3  The average silhouette_score is : 0.4333645131322341
# For no of clusters = 4  The average silhouette_score is : 0.4265416994834592

# %% [markdown]
# > ### **For no of clusters=2, the value of silhouette_score(0.53) which nearest to 1 among all three.So it signifies that the data points are well-assigned and can be interpreted as belonging to an ‘appropriate’ cluster.**

# %% [markdown]
# # Feature Selection

# %%
# Selecting columns
X=training_set1.drop(['SalePrice','Id'],axis=1)
y=training_set1['SalePrice']

# %%
X
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
# ...

# %%
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1121, dtype: int64

# %% [markdown]
# ## 6. Wrapper Method

# %% [markdown]
# > **It follows a greedy search approach by evaluating all the possible combinations of features against the evaluation criterion.**

# %%
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import r2_score
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# %%
# step forward feature selection
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
sfs1 = SFS(RandomForestRegressor(n_jobs=-1),k_features=20,forward=True,floating=False,verbose=2,scoring='r2',cv=3,n_jobs=-1)
sfs1 = sfs1.fit(np.array(X),y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    9.4s finished
#
# [2020-12-10 15:05:48] Features: 1/20 -- score: 0.6904193224437892[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    6.5s finished
#
# [2020-12-10 15:05:54] Features: 2/20 -- score: 0.7360065170328166[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    9.6s finished
#
# [2020-12-10 15:06:04] Features: 3/20 -- score: 0.8091996558930014[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    9.6s finished
#
# [2020-12-10 15:06:14] Features: 4/20 -- score: 0.8502524527267553[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ...

# %%
sfs1.k_feature_idx_
# Out:
# (0, 1, 3, 4, 6, 8, 10, 11, 12, 14, 15, 16, 20, 21, 22, 24, 26, 31, 33, 34)

# %%
X.columns[list(sfs1.k_feature_idx_)]
# Out:
# Index(['MSSubClass', 'LotFrontage', 'OverallQual', 'OverallCond',
#        'YearRemodAdd', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea',
#        'MiscVal'],
#       dtype='object')

# %%
X=X[['BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
       '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'HalfBath', 'BedroomAbvGr',
       'KitchenAbvGr', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea',
       'MiscVal']]
test=test[['BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF', 'CentralAir',
       '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'HalfBath', 'BedroomAbvGr',
       'KitchenAbvGr', 'Fireplaces', 'GarageCars', '3SsnPorch', 'PoolArea',
       'MiscVal']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state=0)

# %%
test=test.dropna()

# %%
X_train
# Out:
#       BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  CentralAir  2ndFlrSF  LowQualFinSF  \
# 1168         626        501         1127           0       872             0
# 1058         936        168         1104           0      1054             0
# 1439         315        114          539           0       685             0
# 949          982        179         1161           0         0             0
# 400          786        474         1260           0         0             0
# ...          ...        ...          ...         ...       ...           ...
# 1345         250        710          960           0         0             0
# 990         1074        322         1396           0       985             0
# 1083         553        698         1251           0         0             0
# 723            0        941          941           0       473             0
# 880          980        110         1090           0         0             0
#
# ...

# %%
X_test
# Out:
#       BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  CentralAir  2ndFlrSF  LowQualFinSF  \
# 1007         273          0          546           0       546             0
# 1196           0        879          879           0       984             0
# 507           27       1191         1218           0         0             0
# 1322         674         76          750           0       862             0
# 659          637        849         1486           0         0             0
# ...          ...        ...          ...         ...       ...           ...
# 606          732        308         1040           0         0             0
# 1336           0       1656         1656           0         0             0
# 1019          16       1346         1362           0         0             0
# 498          450        414          864           0         0             0
# 540         1260        578         1838           0         0             0
#
# ...

# %% [markdown]
# # 7. Regression

# %% [markdown]
# ## 7.1 Linear regression

# %% [markdown]
# > **Linear regression is the most widely used statistical technique; it is a way to model a relationship between two sets of variables.**

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
print("Mean squared error: {}".format(mean_squared_error(y_test, y_pred)))
print("Variance score: {}".format(r2_score(y_test, y_pred)))
print("r2 score: {}".format(r2_score(y_test,y_pred)))
# Out:
# Mean squared error: 3821837928.525035
# Variance score: 0.3387067302858595
# r2 score: 0.3387067302858595

# %%
import statsmodels.api as sm

# %%
x = sm.add_constant(X_test)

# %%
results = sm.OLS(endog = y_test, exog=x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.834
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     70.20
# Date:                Thu, 10 Dec 2020   Prob (F-statistic):           6.89e-73
# Time:                        21:25:16   Log-Likelihood:                -2645.7
# No. Observations:                 225   AIC:                             5323.
# Df Residuals:                     209   BIC:                             5378.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 7.2 Poynomial Regression

# %% [markdown]
# > **Polynomial Regression is a regression algorithm that models the relationship between a dependent(y) and independent variable(x) as nth degree polynomial.**

# %%
from sklearn.preprocessing import PolynomialFeatures
rmses = []
degrees = np.arange(1, 5)
min_rmse, min_deg = 1e10, 0
for deg in degrees:

    # Train features
    poly_features = PolynomialFeatures(degree=deg, include_bias=False)
    x_poly_train = poly_features.fit_transform(X_train)

    # Linear regression
    poly_reg = LinearRegression()
    poly_reg.fit(x_poly_train, y_train)

    # Compare with test data
    x_poly_test = poly_features.fit_transform(X_test)
    poly_predict = poly_reg.predict(x_poly_test)
    poly_mse = mean_squared_error(y_test, poly_predict)
    poly_rmse = np.sqrt(poly_mse)
    rmses.append(poly_rmse)
    
    # Cross-validation of degree
    if min_rmse > poly_rmse:
        min_rmse = poly_rmse
        min_deg = deg

# Plot and present results
print('Best degree {} with RMSE {}'.format(min_deg, min_rmse))
        
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(degrees, rmses)
ax.set_yscale('log')
ax.set_xlabel('Degree')
ax.set_ylabel('RMSE')
# Out:
# Best degree 1 with RMSE 61821.015266048766
# Text(0, 0.5, 'RMSE')

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2)

X_pf=pf.fit_transform(X)

lr=LinearRegression()

lr.fit(X_pf,y_test)

pred=lr.predict(X_pf)

rmse =np.sqrt(mean_squared_error(y_test,pred))
r2 = r2_score(y_test,pred)
print("Mean absolute error is:{}" .format(mean_absolute_error(y_test,pred)))
print("Mean squared error is:{}" .format(mean_squared_error(y_test,pred)))
print("rmse value is:{}" .format(rmse))
print("r2 value is:{}" .format(r2))
# Out:
# Mean absolute error is:21388.586728583443
# Mean squared error is:825293940.9041791
# rmse value is:28727.929631356645
# r2 value is:0.8571992484081031

# %% [markdown]
# ## 7.3 XGBOOST

# %% [markdown]
# > **XGBoost is a decision-tree-based ensemble Machine Learning algorithm that uses a gradient boosting framework. In prediction problems involving unstructured data (images, text, etc.) artificial neural networks tend to outperform all other algorithms or frameworks.**

# %% [markdown]
# ## Hyperparameter tuning for XGBoost

# %%
import xgboost
regressor=xgboost.XGBRegressor()

# %%
## Hyper Parameter Optimization
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]
base_score=[0.25,0.5,0.75,1]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# Set up the random search with 4-fold cross validation
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:   19.4s
# [Parallel(n_jobs=4)]: Done 178 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed:   52.1s finished
# RandomizedSearchCV(cv=5,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=1, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.15, max_delta_step=0, max_depth=5,
#              min_child_weight=2, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
regressor=xgboost.XGBRegressor(base_score=1, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
             importance_type='gain', interaction_constraints='',
             learning_rate=0.15, max_delta_step=0, max_depth=5,
             min_child_weight=2, monotone_constraints='()',
             n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
             reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
             tree_method='exact', validate_parameters=1, verbosity=None)

# %%
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=1, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.15, max_delta_step=0, max_depth=5,
#              min_child_weight=2, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred=regressor.predict(X_test)

# %%
rmse =np.sqrt(mean_squared_error(y_test,y_pred))
r2 = r2_score(y_test,y_pred)

print("Mean absolute error is:{}" .format(mean_absolute_error(y_test,y_pred)))
print("Mean squared error is:{}" .format(mean_squared_error(y_test,y_pred)))
print("rmse value is:{}" .format(rmse))
print("r2value is:{}" .format(r2))
# Out:
# Mean absolute error is:22455.085729166665
# Mean squared error is:1126994159.6260679
# rmse value is:33570.733677208606
# r2value is:0.8049960080187162

# %% [markdown]
# ## 7.4 Random Forest

# %% [markdown]
# > ### **A random forest is an ensemble model that consists of many decision trees. Predictions are made by averaging the predictions of each decision tree.**

# %% [markdown]
# ## Hyperparameter tuning for Random Forest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
 {'n_estimators': [3, 10, 30,50,100], 'max_features': [8,10,12,14]},
 {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [9,11,13]},
 ]

forest_reg = RandomForestRegressor()

grid_search = GridSearchCV(forest_reg, param_grid, cv=5,scoring='neg_mean_squared_error',return_train_score=True)

# %%
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 100}

# %%
forest_reg_best = RandomForestRegressor(max_features = 8, n_estimators = 100)
forest_reg_best.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_features=8)

# %%
y_pred = forest_reg_best.predict(X_test)
rf_mse = mean_squared_error(y_test, y_pred)
rf_rmse = np.sqrt(rf_mse)
print("rmse value is:{}" .format(rf_rmse))
r2 = r2_score(y_test,y_pred)
print("r2 value is:{}" .format(r2))
print("Mean absolute error is:{}" .format(mean_absolute_error(y_test,y_pred)))
print("Mean squared error is:{}" .format(mean_squared_error(y_test,y_pred)))
# Out:
# rmse value is:34142.08327860086
# r2 value is:0.798301870239398
# Mean absolute error is:21894.47912042328
# Mean squared error is:1165681850.6029165

# %% [markdown]
# # 8. PREDICTION ON TEST DATA

# %% [markdown]
# > **After analysing performance measures for regression models. We conclude that polynomial regression is coming out to be the best. For final prediction, we fit polynomial regression on our test data.**

# %%
y_poly=lr.predict(pf.fit_transform(test))
y_poly=pd.DataFrame(y_poly,columns=['Sale Price'])
y_poly
# Out:
#          Sale Price
# 0     117741.900851
# 1     866817.334953
# 2     202868.410144
# 3     192776.714106
# 4     164653.090841
# ...             ...
# 1452  102299.485787
# 1453  113001.138307
# 1454  137944.513136
# 1455  146487.247787
# 1456  287187.054463
#
# [1457 rows x 1 columns]

# %%
test["SalePrice"] = y_poly
test.to_csv('Submission_House_Price1.csv')

# %%
test.head(50)
# Out:
#     BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  CentralAir  2ndFlrSF  LowQualFinSF  \
# 0        468.0      270.0        882.0           0         0             0
# 1        923.0      406.0       1329.0           0         0             0
# 2        791.0      137.0        928.0           0       701             0
# 3        602.0      324.0        926.0           0       678             0
# 4        263.0     1017.0       1280.0           0         0             0
# 5          0.0      763.0        763.0           0       892             0
# 6        935.0      233.0       1168.0           0         0             0
# 7          0.0      789.0        789.0           0       676             0
# 8        637.0      663.0       1300.0           0         0             0
# 9        804.0        0.0        882.0           0         0             0
# 10      1051.0      354.0       1405.0           0         0             0
# ...

# %% [markdown]
# # Thank you!
