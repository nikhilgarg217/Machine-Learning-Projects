# %% [markdown]
# # Credit Card

# %% [markdown]
# # Aim- To Identify Marketing Strategy by analysing customer credit card usage

# %% [markdown]
# # Data Preprocessing and Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Credit Card.csv',index_col=0)
df
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
# ...              ...                ...        ...               ...
# C19186     28.493517           1.000000     291.12              0.00
# C19187     19.183215           1.000000     300.00              0.00
# C19188     23.398673           0.833333     144.40              0.00
# C19189     13.457564           0.833333       0.00              0.00
# C19190    372.708075           0.666667    1093.25           1093.25
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# ...

# %%
df.head()
# Out:
#              BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# CUST_ID
# C10001     40.900749           0.818182      95.40              0.00
# C10002   3202.467416           0.909091       0.00              0.00
# C10003   2495.148862           1.000000     773.17            773.17
# C10004   1666.670542           0.636364    1499.00           1499.00
# C10005    817.714335           1.000000      16.00             16.00
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# CUST_ID
# C10001                     95.4      0.000000             0.166667
# C10002                      0.0   6442.945483             0.000000
# C10003                      0.0      0.000000             1.000000
# C10004                      0.0    205.788017             0.083333
# C10005                      0.0      0.000000             0.083333
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# CUST_ID
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8950 entries, C10001 to C19190
# Data columns (total 17 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
# Heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot=True)

# %%
sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
ax = sns.distplot(df['PURCHASES_FREQUENCY'])
plt.show()

# %%
# histogram
df.hist(['CREDIT_LIMIT'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000211B5709908>]],
#       dtype=object)

# %%
# Boxplot
sns.set(style="whitegrid")
ax = sns.boxplot(x=df['BALANCE'])
plt.show()

# %%
# Boxplot
sns.set(style="whitegrid")
ax = sns.boxplot(x=df['CREDIT_LIMIT'])
plt.show()

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
X = df.iloc[:, [1,13]].values #1,13 is used for selecting my 2 columns that is Balance and Credit_Limit

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Y= scaler.fit_transform(X)

# %% [markdown]
# # K Means Clustering

# %% [markdown]
# # PERFORMANCE MEASURES

# %% [markdown]
# #   1) ELBOW METHOD

# %%
from sklearn.cluster import KMeans
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters = k, init = 'k-means++', max_iter=300, n_init=10)
    kmeans.fit(Y)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters = 6, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
kmeans.inertia_
# Out:
# 2249.0032392572575

# %% [markdown]
# #   2) SILHOUETTE METHOD

# %%
from sklearn.metrics import silhouette_score
silhouette_coefficients = []
# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter=300, n_init=10)
    kmeans.fit(Y)
    score = silhouette_score(Y, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.plot(range(2, 11), silhouette_coefficients)
plt.title('Silhouette Coefficients')
plt.xlabel('Number of clusters')
plt.ylabel('silhouette_coefficients')
plt.show()

# %%
kmeans = KMeans(n_clusters = 9, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
kmeans_silhouette = silhouette_score(Y, kmeans.labels_)

# %%
kmeans_silhouette
# Out:
# 0.5181206645471859

# %%
kmeans = KMeans(n_clusters = 6, init = 'k-means++', max_iter=300, n_init=10)
y_kmeans = kmeans.fit_predict(Y)

# %%
kmeans_silhouette = silhouette_score(Y, kmeans.labels_)

# %%
kmeans_silhouette
# Out:
# 0.5914181936145516

# %% [markdown]
# As observed with k=9 the silhouette score reduces hence we can claim that k=6 gives optimal clusters.

# %% [markdown]
# # K Means Clustering Graph

# %%
plt.scatter(Y[y_kmeans == 0, 0], Y[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1') #careful
plt.scatter(Y[y_kmeans == 1, 0], Y[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2') #standard
plt.scatter(Y[y_kmeans == 2, 0], Y[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3') #Target
plt.scatter(Y[y_kmeans == 3, 0], Y[y_kmeans == 3, 1], s = 100, c = 'pink', label = 'Cluster 4') #careful
plt.scatter(Y[y_kmeans == 4, 0], Y[y_kmeans == 4, 1], s = 100, c = 'purple', label = 'Cluster 5') #standard
plt.scatter(Y[y_kmeans == 5, 0], Y[y_kmeans == 5, 1], s = 100, c = 'grey', label = 'Cluster 6') #Target
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Balance')
plt.ylabel('Credit_Limit')
plt.legend()
plt.show()

# %% [markdown]
# # Hierarchical clustering

# %%
# Single Linkage
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'single')
y_hc = hc.fit_predict(Y)

# %%
plt.scatter(Y[y_hc == 0, 0], Y[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(Y[y_hc == 1, 0], Y[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(Y[y_hc == 2, 0], Y[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(Y[y_hc == 3, 0], Y[y_hc == 3, 1], s = 100, c = 'pink', label = 'Cluster 4')
plt.scatter(Y[y_hc == 4, 0], Y[y_hc == 4, 1], s = 100, c = 'purple', label = 'Cluster 5')
plt.scatter(Y[y_hc == 5, 0], Y[y_hc == 5, 1], s = 100, c = 'grey', label = 'Cluster 6')
plt.title('Clusters of points')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
# Average Linkage
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 6, affinity = 'euclidean', linkage = 'average')
y_hc = hc.fit_predict(Y)

# %%
plt.scatter(Y[y_hc == 0, 0], Y[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(Y[y_hc == 1, 0], Y[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(Y[y_hc == 2, 0], Y[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(Y[y_hc == 3, 0], Y[y_hc == 3, 1], s = 100, c = 'pink', label = 'Cluster 4')
plt.scatter(Y[y_hc == 4, 0], Y[y_hc == 4, 1], s = 100, c = 'purple', label = 'Cluster 5')
plt.scatter(Y[y_hc == 5, 0], Y[y_hc == 5, 1], s = 100, c = 'grey', label = 'Cluster 6')
plt.title('Clusters of points')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
#Dendogram
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(Y, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
plt.show()

# %% [markdown]
# # THANK YOU
